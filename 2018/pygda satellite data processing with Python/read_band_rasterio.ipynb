# %%
# %matplotlib notebook
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# %%
# Checking the versions of packages
print('rasterio version: ', rasterio.__version__)
# Out:
# rasterio version:  0.36.0

# %%
band4 = rasterio.open('LC08_L1TP_186024_20160630_20170323_01_T1/LC08_L1TP_186024_20160630_20170323_01_T1_B4.TIF')

# %%
band4.name
# Out:
# 'LC08_L1TP_186024_20160630_20170323_01_T1/LC08_L1TP_186024_20160630_20170323_01_T1_B4.TIF'

# %%
band4.mode
# Out:
# 'r'

# %%
band4.closed
# Out:
# False

# %%
band4.count
# Out:
# 1

# %%
band4.width
# Out:
# 7761

# %%
band4.height
# Out:
# 7861

# %%
band4.bounds
# Out:
# BoundingBox(left=567285.0, bottom=5611785.0, right=800115.0, top=5847615.0)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)

ax.imshow(band4.read(1), cmap='gray')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
np.max(band4.read(1))
# Out:
# 65535
